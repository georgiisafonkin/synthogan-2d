# %% [markdown]
# # Demo: GAN Inference
#
# This notebook demonstrates how to use the GAN inference pipeline.

# %%
# Import necessary modules
import sys
sys.path.append('..')

from gan_infer.gan_infer import GANInfer
from core.io_npy import load_npy, save_npy

# %%
# Load example data
seismic_data = load_npy('../demo/seismic_example.npy')
print(f"Loaded seismic data shape: {seismic_data.shape}")

# %%
# Run inference
gan = GANInfer(model_path='../gan_infer/model/model.h5')
result = gan.infer(seismic_data)
